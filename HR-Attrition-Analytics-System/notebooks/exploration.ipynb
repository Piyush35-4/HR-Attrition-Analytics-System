# %% [markdown]
# # HR Attrition Analytics — Exploratory Notebook
#
# This notebook walks through the full data analysis step-by-step.
#
# **Run `python main.py` from the project root before running this notebook.**

# %%
import sys
sys.path.insert(0, '..')  

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_theme(style='whitegrid')
print('Libraries loaded successfully!')
# Out:
# Libraries loaded successfully!

# %% [markdown]
# ## 1. Load the Dataset

# %%
df = pd.read_csv('../data/WA_Fn-UseC_-HR-Employee-Attrition.csv')
print(f'Shape: {df.shape}')
df.head()

# %% [markdown]
# ## 2. Basic Info

# %%
print('Data Types:\n')
print(df.dtypes)
print('\nMissing Values:\n')
print(df.isnull().sum())

# %% [markdown]
# ## 3. Attrition Distribution

# %%
df['Attrition'].value_counts().plot(kind='bar', color=['#2196F3','#F44336'])
plt.title('Attrition Distribution')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Age vs Attrition

# %%
sns.histplot(data=df, x='Age', hue='Attrition', bins=20, kde=True)
plt.title('Age vs Attrition')
plt.show()

# %% [markdown]
# ## 5. Income vs Attrition

# %%
sns.boxplot(data=df, x='Attrition', y='MonthlyIncome')
plt.title('Monthly Income vs Attrition')
plt.show()

# %% [markdown]
# ## 6. Run Full Preprocessing & Training

# %%
from src.preprocessing import preprocess_for_training
from src.train_model import train_random_forest
from src.utils import evaluate_model

X_train, X_test, y_train, y_test, features, scaler, encoders = preprocess_for_training()
rf = train_random_forest(X_train, y_train)
metrics = evaluate_model(rf, X_test, y_test, 'Random Forest')
